# %%
pip install numpy pandas matplotlib seaborn scikit-learn jupyter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures,StandardScaler
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline

# %%
X= 6* np.random.rand(200,1)-3
y = 0.8 *X**2 +0.9*X+2+np.random.randn(200,1)

# y=0.8x^2+0.9x+2

# %%
plt.plot(X,y,'b.')
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
X_tain,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_tain,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.1454238781229258

# %%
plt.plot(X_tain,lr.predict(X_tain),color='r')
plt.plot(X,y,"b.")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
poly = PolynomialFeatures(degree=2)

X_tain_trans = poly.fit_transform(X_tain)
X_test_trans = poly.transform(X_test)

# %%
print(X_tain[0])
print(X_tain_trans[0])
# Out:
# [1.5060855]
# [1.         1.5060855  2.26829353]

# %%
lr = LinearRegression()
lr.fit(X_tain_trans,y_train)
# Out:
# LinearRegression()

# %%
r2_score(y_test,y_pred)
# Out:
# 0.1454238781229258

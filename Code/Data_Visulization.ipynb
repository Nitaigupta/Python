# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.7

# %%
x=[1,2,3,4]
y=[1,4,9,16]
plt.plot(x,y)
plt.show()

# %%
plt.bar([0,1,2],[10,20,15])
plt.show()

# %%
plt.bar([0,1,2],[10,20,15])
plt.bar([0,1,2],[10,20,95])
plt.show()

# %%
ls=[0,3,9]
plt.bar(ls,[10,20,15],width=1.5,label="Current year" , tick_label=["Gold","platnium","silver"])
plt.bar(ls,[15,25,45],width=-0.5,label="Next year" )
plt.legend()
plt.show()

# %%
subjects="Maths","chem","Physics","English"
weightage=[20,10,15,5]
plt.pie(weightage,labels=subjects)
plt.show()

# %%
pip install numpy pandas matplotlib seaborn scikit-learn jupyter
# Out:
# Requirement already satisfied: numpy in d:\ml\venv\lib\site-packages (2.2.6)
# Requirement already satisfied: pandas in d:\ml\venv\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in d:\ml\venv\lib\site-packages (3.10.7)
# Requirement already satisfied: seaborn in d:\ml\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in d:\ml\venv\lib\site-packages (1.7.2)
# Requirement already satisfied: jupyter in d:\ml\venv\lib\site-packages (1.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\ml\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\ml\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\ml\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\ml\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\ml\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\ml\venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\ml\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\ml\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\ml\venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in d:\ml\venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: scipy>=1.8.0 in d:\ml\venv\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\ml\venv\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\ml\venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: notebook in d:\ml\venv\lib\site-packages (from jupyter) (7.4.7)
# Requirement already satisfied: jupyter-console in d:\ml\venv\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in d:\ml\venv\lib\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in d:\ml\venv\lib\site-packages (from jupyter) (6.30.1)
# Requirement already satisfied: ipywidgets in d:\ml\venv\lib\site-packages (from jupyter) (8.1.8)
# Requirement already satisfied: jupyterlab in d:\ml\venv\lib\site-packages (from jupyter) (4.4.10)
# Requirement already satisfied: six>=1.5 in d:\ml\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in d:\ml\venv\lib\site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in d:\ml\venv\lib\site-packages (from ipykernel->jupyter) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in d:\ml\venv\lib\site-packages (from ipykernel->jupyter) (8.37.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in d:\ml\venv\lib\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\ml\venv\lib\site-packages (from ipykernel->jupyter) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\ml\venv\lib\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in d:\ml\venv\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in d:\ml\venv\lib\site-packages (from ipykernel->jupyter) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in d:\ml\venv\lib\site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in d:\ml\venv\lib\site-packages (from ipykernel->jupyter) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in d:\ml\venv\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: colorama in d:\ml\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: decorator in d:\ml\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: exceptiongroup in d:\ml\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in d:\ml\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\ml\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in d:\ml\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.19.2)
# Requirement already satisfied: stack_data in d:\ml\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in d:\ml\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.15.0)
# Requirement already satisfied: wcwidth in d:\ml\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\ml\venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in d:\ml\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.4.0)
# Requirement already satisfied: pywin32>=300 in d:\ml\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (311)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in d:\ml\venv\lib\site-packages (from ipywidgets->jupyter) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in d:\ml\venv\lib\site-packages (from ipywidgets->jupyter) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in d:\ml\venv\lib\site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in d:\ml\venv\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in d:\ml\venv\lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\ml\venv\lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in d:\ml\venv\lib\site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in d:\ml\venv\lib\site-packages (from jupyterlab->jupyter) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in d:\ml\venv\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in d:\ml\venv\lib\site-packages (from jupyterlab->jupyter) (78.1.1)
# Requirement already satisfied: tomli>=1.2.2 in d:\ml\venv\lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: anyio in d:\ml\venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.11.0)
# Requirement already satisfied: certifi in d:\ml\venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\ml\venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in d:\ml\venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\ml\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\ml\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in d:\ml\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\ml\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in d:\ml\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in d:\ml\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in d:\ml\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\ml\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in d:\ml\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in d:\ml\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in d:\ml\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.9.0)
# Requirement already satisfied: babel>=2.10 in d:\ml\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in d:\ml\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in d:\ml\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.25.1)
# Requirement already satisfied: requests>=2.31 in d:\ml\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in d:\ml\venv\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in d:\ml\venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\ml\venv\lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in d:\ml\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\ml\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\ml\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\ml\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.28.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\ml\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in d:\ml\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in d:\ml\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\ml\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in d:\ml\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in d:\ml\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in d:\ml\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in d:\ml\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in d:\ml\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in d:\ml\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in d:\ml\venv\lib\site-packages (from nbconvert->jupyter) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in d:\ml\venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.3.0)
# Requirement already satisfied: defusedxml in d:\ml\venv\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\ml\venv\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\ml\venv\lib\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in d:\ml\venv\lib\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\ml\venv\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in d:\ml\venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in d:\ml\venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\ml\venv\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\ml\venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ml\venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in d:\ml\venv\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in d:\ml\venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in d:\ml\venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.23)
# Requirement already satisfied: soupsieve>1.2 in d:\ml\venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in d:\ml\venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.4.0)
# Requirement already satisfied: executing>=1.2.0 in d:\ml\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\ml\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (3.0.0)
# Requirement already satisfied: pure_eval in d:\ml\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter_contrib_nbextensions
# Out:
# Requirement already satisfied: jupyter_contrib_nbextensions in d:\ml\venv\lib\site-packages (0.7.0)
# Requirement already satisfied: ipython_genutils in d:\ml\venv\lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter_contrib_core>=0.3.3 in d:\ml\venv\lib\site-packages (from jupyter_contrib_nbextensions) (0.4.2)
# Requirement already satisfied: jupyter_core in d:\ml\venv\lib\site-packages (from jupyter_contrib_nbextensions) (5.8.1)
# Requirement already satisfied: jupyter_highlight_selected_word>=0.1.1 in d:\ml\venv\lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter_nbextensions_configurator>=0.4.0 in d:\ml\venv\lib\site-packages (from jupyter_contrib_nbextensions) (0.6.4)
# Requirement already satisfied: nbconvert>=6.0 in d:\ml\venv\lib\site-packages (from jupyter_contrib_nbextensions) (7.16.6)
# Requirement already satisfied: notebook>=6.0 in d:\ml\venv\lib\site-packages (from jupyter_contrib_nbextensions) (7.4.7)
# Requirement already satisfied: tornado in d:\ml\venv\lib\site-packages (from jupyter_contrib_nbextensions) (6.5.2)
# Requirement already satisfied: traitlets>=4.1 in d:\ml\venv\lib\site-packages (from jupyter_contrib_nbextensions) (5.14.3)
# Requirement already satisfied: lxml in d:\ml\venv\lib\site-packages (from jupyter_contrib_nbextensions) (6.0.2)
# Requirement already satisfied: setuptools in d:\ml\venv\lib\site-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions) (78.1.1)
# Requirement already satisfied: jupyter-server in d:\ml\venv\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.17.0)
# Requirement already satisfied: pyyaml in d:\ml\venv\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0.3)
# Requirement already satisfied: beautifulsoup4 in d:\ml\venv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in d:\ml\venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (6.3.0)
# Requirement already satisfied: defusedxml in d:\ml\venv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in d:\ml\venv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.6)
# Requirement already satisfied: jupyterlab-pygments in d:\ml\venv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in d:\ml\venv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\ml\venv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in d:\ml\venv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in d:\ml\venv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.10.4)
# Requirement already satisfied: packaging in d:\ml\venv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (25.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\ml\venv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in d:\ml\venv\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.19.2)
# Requirement already satisfied: typing-extensions in d:\ml\venv\lib\site-packages (from mistune<4,>=2.0.3->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.15.0)
# Requirement already satisfied: webencodings in d:\ml\venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in d:\ml\venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.4.0)
# Requirement already satisfied: platformdirs>=2.5 in d:\ml\venv\lib\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (4.4.0)
# Requirement already satisfied: pywin32>=300 in d:\ml\venv\lib\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (311)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\ml\venv\lib\site-packages (from nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (8.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\ml\venv\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in d:\ml\venv\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (27.1.0)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\ml\venv\lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in d:\ml\venv\lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.25.1)
# Requirement already satisfied: attrs>=22.2.0 in d:\ml\venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\ml\venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\ml\venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\ml\venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.28.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in d:\ml\venv\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (2.28.0)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.9 in d:\ml\venv\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (4.4.10)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in d:\ml\venv\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in d:\ml\venv\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (4.11.0)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\ml\venv\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in d:\ml\venv\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\ml\venv\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in d:\ml\venv\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in d:\ml\venv\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\ml\venv\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in d:\ml\venv\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in d:\ml\venv\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in d:\ml\venv\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in d:\ml\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in d:\ml\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in d:\ml\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (6.30.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\ml\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (2.3.0)
# Requirement already satisfied: tomli>=1.2.2 in d:\ml\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (2.3.0)
# Requirement already satisfied: certifi in d:\ml\venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\ml\venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (1.0.9)
# Requirement already satisfied: idna in d:\ml\venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\ml\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (0.16.0)
# Requirement already satisfied: babel>=2.10 in d:\ml\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in d:\ml\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.12.1)
# Requirement already satisfied: requests>=2.31 in d:\ml\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.32.5)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\ml\venv\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in d:\ml\venv\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in d:\ml\venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in d:\ml\venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in d:\ml\venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in d:\ml\venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (8.37.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\ml\venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in d:\ml\venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in d:\ml\venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (7.1.0)
# Requirement already satisfied: colorama in d:\ml\venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (0.4.6)
# Requirement already satisfied: decorator in d:\ml\venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in d:\ml\venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\ml\venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.52)
# Requirement already satisfied: stack_data in d:\ml\venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (0.6.3)
# Requirement already satisfied: wcwidth in d:\ml\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\ml\venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.5)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\ml\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (4.0.0)
# Requirement already satisfied: rfc3339-validator in d:\ml\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\ml\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.1)
# Requirement already satisfied: fqdn in d:\ml\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in d:\ml\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in d:\ml\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in d:\ml\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.1.0)
# Requirement already satisfied: uri-template in d:\ml\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in d:\ml\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (25.10.0)
# Requirement already satisfied: six>=1.5 in d:\ml\venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\ml\venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ml\venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in d:\ml\venv\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in d:\ml\venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.0.0)
# Requirement already satisfied: pycparser in d:\ml\venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.23)
# Requirement already satisfied: soupsieve>1.2 in d:\ml\venv\lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in d:\ml\venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.4.0)
# Requirement already satisfied: tzdata in d:\ml\venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2025.2)
# Requirement already satisfied: executing>=1.2.0 in d:\ml\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\ml\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.0)
# Requirement already satisfied: pure_eval in d:\ml\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
class MeraLR:
    
    def __init__(self):
        self.m = None
        self.b = None
        
    def fit(self,X_train,y_train):
        
        num = 0
        den = 0
        
        for i in range(X_train.shape[0]):
            
            num = num + ((X_train[i] - X_train.mean())*(y_train[i] - y_train.mean()))
            den = den + ((X_train[i] - X_train.mean())*(X_train[i] - X_train.mean()))
        
        self.m = num/den
        self.b = y_train.mean() - (self.m * X_train.mean())
        print(self.m)
        print(self.b)       
    
    def predict(self,X_test):
        
        print(X_test)
        
        return self.m * X_test + self.b

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X = df.iloc[:,0].values
y=df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape[0]
# Out:
# 160

# %%
lr = MeraLR()

# %%
lr.fit(X_train,y_train)
# Out:
# 0.5579519734250721
# -0.8961119222429152
